# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import textwrap
# 生成虚构的真实标签和预测标签
np.random.seed(42)
true_labels = np.random.choice([0, 1], size=100, p=[0.7, 0.3])
predicted_labels = np.random.choice([0, 1], size=100, p=[0.8, 0.2])

# 计算混淆矩阵
conf_matrix = confusion_matrix(true_labels, predicted_labels)

print(conf_matrix)
# Out:
# [[52 18]
#  [24  6]]

# %%
# 绘制混淆矩阵
plt.figure(figsize=(8, 8))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
title_text="conf_matrix"
plt.title(title_text,loc='center')

classes = ['Negative', 'Adversarial']
tick_marks = np.arange(len(classes))

plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes,rotation=90)

plt.xlabel('Predicted')
plt.ylabel('Actual',rotation=90)

# 在图表中添加数字标签
for i in range(len(classes)):
    for j in range(len(classes)):
        plt.text(j, i, str(conf_matrix[i, j]), fontsize=12,horizontalalignment="center", color="black")

plt.show()

# %%
# from Model.DAGMM import *
# dagmm=DAGMM(3,64,64)
# enc, dec, z, gamma=dagmm(x)
# print(z.shape)
# print(gamma.shape)
# phi, mu, cov = dagmm.compute_gmm_params(z, gamma)
            
# batch_gamma_sum = torch.sum(gamma, dim=0)    
# #dec.shape
