# %%
import torch
x=torch.randn([64,3,64,64])
x
# Out:
# tensor([[[[-6.6156e-01, -1.1297e+00,  1.2267e+00,  ...,  1.9467e-01,
#             6.4750e-01,  3.8215e-01],
#           [ 1.4557e+00, -8.5354e-01,  9.8641e-01,  ...,  2.2386e-01,
#             8.3152e-01,  6.2716e-01],
#           [-8.4540e-02, -1.9059e-03,  1.5965e-01,  ...,  8.9472e-01,
#            -6.5863e-01, -4.9926e-01],
#           ...,
#           [ 1.1684e+00,  1.3287e-01,  2.2614e+00,  ..., -8.0298e-01,
#             8.9813e-01,  1.0304e+00],
#           [-1.2608e+00,  1.0784e+00,  9.7896e-01,  ...,  2.8617e-01,
#             3.5108e-01,  3.1037e+00],
#           [ 2.7171e-01, -5.5515e-01, -3.4905e-01,  ..., -3.9574e-01,
#            -1.3981e-01, -1.0555e+00]],
#
#          [[ 1.6563e-02, -1.7172e+00,  1.0671e+00,  ..., -6.7450e-01,
#            -2.2904e+00,  2.8272e-03],
#           [ 7.1565e-02,  6.4479e-01,  1.7906e+00,  ...,  2.2270e+00,
#            -6.1484e-01,  1.0566e+00],
#           [ 1.7893e+00, -5.9398e-02, -5.3716e-01,  ..., -7.4442e-01,
# ...

# %%
from Model.DAGMM import *
dagmm=DAGMM(3,64,64)
enc, dec, z, gamma=dagmm(x)
#dec.shape
# Out:
# torch.Size([64])
# torch.Size([64])
# torch.Size([64, 3])
# torch.Size([64, 2])
